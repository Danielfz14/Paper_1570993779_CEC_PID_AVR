# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
import numpy as np
import pandas as pd

import customhys as mh
from customhys import metaheuristic as mh
from customhys import benchmark_func as bf
from customhys import hyperheuristic as hh
import numpy as np
import matplotlib.pyplot as plt

import control as co
import numpy as np
from control.matlab import *
import matplotlib.pyplot as plt
from scipy.integrate import simps
import matlab.engine 
eng=matlab.engine.start_matlab()
eng = matlab.engine.start_matlab("-desktop")
# Out:
# benchmark_func.py:29: ImportWarning: `optproblems` not found! Please, install it to use the cec2005 benchmark functions

# %%
class P1(bf.BasicProblem):
    def __init__(self, variable_num):
        super().__init__(variable_num)
        self.max_search_range =np.array([1.5, 1.5, 1 ])                    
        self.min_search_range = np.array([0.000001, 0.0000001,0.0000001]) 
        self.global_optimum_solution = 0.0
    def get_func_val(self, variables, *args):
        fcost=eng.AVR_PID_CEC_p1(float(variables[0]),float(variables[1]),float(variables[2]))
        return fcost

# %%
best_solutions = []
perf= []
hist_curr1= []
hist_best1= []

parameters = dict(
    cardinality=3,  # Max. numb. of SOs in MHs, lvl:1
    cardinality_min=2,  # Min. numb. of SOs in MHs, lvl:1
    num_iterations=15,  # Iterations a MH performs, lvl:1
    num_agents=10,  # Agents in population,     lvl:1
    as_mh=True,  # HH sequence as a MH?,     lvl:2
    num_replicas=10,  # Replicas per each MH,     lvl:2
    num_steps=10,  # Trials per HH step,       lvl:2
    stagnation_percentage=0.37,  # Stagnation percentage,    lvl:2
    max_temperature=100,  # Initial temperature (SA), lvl:2
    min_temperature=1e-6,  # Min temperature (SA),     lvl:2
    cooling_rate=1e-3,  # Cooling rate (SA),        lvl:2
    temperature_scheme='fast',  # Temperature updating (SA),lvl:2
    acceptance_scheme='exponential',  # Acceptance mode,          lvl:2
    allow_weight_matrix=True,  # Weight matrix,            lvl:2
    trial_overflow=False,  # Trial overflow policy,    lvl:2
    learnt_dataset=None,  # If it is a learnt dataset related with the heuristic space
    repeat_operators=True,  # Allow repeating SOs inSeq,lvl:2
    verbose=True,  # Verbose process,          lvl:2
    learning_portion=0.37,  # Percent of seqs to learn  lvl:2
    solver='static')  # Indicate which solver use lvl:1

heuristic_space="short_collection2.txt"

with open('C:/Users/A00836756/AppData/Local/anaconda3/Lib/site-packages/customhys/collections/' + heuristic_space, 'r', encoding='utf-8') as operators_file:
    heuristic_space_list = [eval(line.rstrip('\n')) for line in operators_file]
for i in range(1, 20):
    print("Repeticion:")
    print(i)
    fun = P1(3)
    prob = fun. get_formatted_problem ()
    file_label1 = f'CEC_p1_PID_exp{i}'
    hyp = hh.Hyperheuristic(heuristic_space_list,problem=prob, parameters=parameters, file_label=file_label1)
    best_sol, best_perf, hist_curr, hist_best =hyp.solve()
    #search_operators = hyp.get_operators(best_sol)
    #print(search_operators)
    best_solutions.append(best_sol)
    perf.append(best_perf)
    hist_curr1.append(hist_curr)
    hist_best1.append(hist_best)
# Out:
# Repeticion:
# 1
# CEC_p1_PID_exp1 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.61e+00 [Initial]
# CEC_p1_PID_exp1 :: Step:    1, Action: Restart     , Temp: 1.00e+02, Card:   2, candPerf: 1.51e+01, currPerf: 1.61e+00, bestPerf: 1.61e+00 , [Delta: 1.35e+01, ArgProb: -5.18e-02, Prob: 0.95] A
# CEC_p1_PID_exp1 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 9.24e+00, currPerf: 1.51e+01, bestPerf: 1.61e+00 , [Delta: -5.87e+00, ArgProb: 4.50e-02, Prob: 1.00] A
# CEC_p1_PID_exp1 :: Step:    3, Action: Shift       , Temp: 3.33e+01, Card:   2, candPerf: 3.96e+00, currPerf: 9.24e+00, bestPerf: 1.61e+00 , [Delta: -5.28e+00, ArgProb: 6.08e-02, Prob: 1.00] A
# CEC_p1_PID_exp1 :: Step:    4, Action: Swap        , Temp: 2.50e+01, Card:   2, candPerf: 2.36e+00, currPerf: 3.96e+00, bestPerf: 1.61e+00 , [Delta: -1.60e+00, ArgProb: 2.46e-02, Prob: 1.00] A
#
# BEST --> Perf: 1.60772716741452, e-Sol: [5 2]
# Repeticion:
# 2
# CEC_p1_PID_exp2 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.81e+02 [Initial]
# CEC_p1_PID_exp2 :: Step:    1, Action: Shift       , Temp: 1.00e+02, Card:   2, candPerf: 1.11e+01, currPerf: 1.81e+02, bestPerf: 1.81e+02 , [Delta: -1.70e+02, ArgProb: 9.33e-03, Prob: 1.00] A+
# CEC_p1_PID_exp2 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 9.00e+00, currPerf: 1.11e+01, bestPerf: 1.11e+01 , [Delta: -2.10e+00, ArgProb: 2.31e-04, Prob: 1.00] A+
# CEC_p1_PID_exp2 :: Step:    3, Action: Shift       , Temp: 3.33e+01, Card:   2, candPerf: 7.62e+00, currPerf: 9.00e+00, bestPerf: 9.00e+00 , [Delta: -1.38e+00, ArgProb: 2.27e-04, Prob: 1.00] A+
# CEC_p1_PID_exp2 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 8.73e+01, currPerf: 7.62e+00, bestPerf: 7.62e+00 , [Delta: 7.97e+01, ArgProb: -1.75e-02, Prob: 0.98] A
# CEC_p1_PID_exp2 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   2, candPerf: 3.49e+02, currPerf: 8.73e+01, bestPerf: 7.62e+00 , [Delta: 2.62e+02, ArgProb: -7.21e-02, Prob: 0.93]
# CEC_p1_PID_exp2 :: Step:    6, Action: Restart     , Temp: 1.67e+01, Card:   2, candPerf: 8.08e+00, currPerf: 8.73e+01, bestPerf: 7.62e+00 , [Delta: -7.92e+01, ArgProb: 2.61e-02, Prob: 1.00] A
# CEC_p1_PID_exp2 :: Step:    7, Action: LocalShift  , Temp: 1.43e+01, Card:   2, candPerf: 3.31e+00, currPerf: 8.08e+00, bestPerf: 7.62e+00 , [Delta: -4.77e+00, ArgProb: 1.84e-03, Prob: 1.00] A+
# CEC_p1_PID_exp2 :: Step:    8, Action: Add         , Temp: 1.25e+01, Card:   3, candPerf: 1.75e+00, currPerf: 3.31e+00, bestPerf: 3.31e+00 , [Delta: -1.56e+00, ArgProb: 6.85e-04, Prob: 1.00] A+
# CEC_p1_PID_exp2 :: Step:    9, Action: Restart     , Temp: 1.11e+01, Card:   3, candPerf: 9.07e+00, currPerf: 1.75e+00, bestPerf: 1.75e+00 , [Delta: 7.32e+00, ArgProb: -3.62e-03, Prob: 1.00] A
# CEC_p1_PID_exp2 :: Step:   10, Action: Remove      , Temp: 1.00e+01, Card:   2, candPerf: 1.26e+01, currPerf: 9.07e+00, bestPerf: 1.75e+00 , [Delta: 3.51e+00, ArgProb: -1.93e-03, Prob: 1.00] A
#
# BEST --> Perf: 1.750223711680178, e-Sol: [12 12 18]
# Repeticion:
# 3
# CEC_p1_PID_exp3 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 4.85e+00 [Initial]
# CEC_p1_PID_exp3 :: Step:    1, Action: Restart     , Temp: 1.00e+02, Card:   2, candPerf: 3.56e+00, currPerf: 4.85e+00, bestPerf: 4.85e+00 , [Delta: -1.29e+00, ArgProb: 2.21e-03, Prob: 1.00] A+
# CEC_p1_PID_exp3 :: Step:    2, Action: Restart     , Temp: 5.00e+01, Card:   2, candPerf: 1.48e+00, currPerf: 3.56e+00, bestPerf: 3.56e+00 , [Delta: -2.07e+00, ArgProb: 7.09e-03, Prob: 1.00] A+
# CEC_p1_PID_exp3 :: Step:    3, Action: Shift       , Temp: 3.33e+01, Card:   2, candPerf: 1.35e+00, currPerf: 1.48e+00, bestPerf: 1.48e+00 , [Delta: -1.34e-01, ArgProb: 6.85e-04, Prob: 1.00] A+
# CEC_p1_PID_exp3 :: Step:    4, Action: RollMany    , Temp: 2.50e+01, Card:   2, candPerf: 2.89e+00, currPerf: 1.35e+00, bestPerf: 1.35e+00 , [Delta: 1.54e+00, ArgProb: -1.05e-02, Prob: 0.99] A
# CEC_p1_PID_exp3 :: Step:    5, Action: Restart     , Temp: 2.00e+01, Card:   2, candPerf: 4.03e+01, currPerf: 2.89e+00, bestPerf: 1.35e+00 , [Delta: 3.74e+01, ArgProb: -3.20e-01, Prob: 0.73] A
# CEC_p1_PID_exp3 :: Step:    6, Action: Roll        , Temp: 1.67e+01, Card:   2, candPerf: 1.07e+02, currPerf: 4.03e+01, bestPerf: 1.35e+00 , [Delta: 6.71e+01, ArgProb: -6.88e-01, Prob: 0.50] A
# CEC_p1_PID_exp3 :: Step:    7, Action: Roll        , Temp: 1.43e+01, Card:   2, candPerf: 6.72e+01, currPerf: 1.07e+02, bestPerf: 1.35e+00 , [Delta: -4.02e+01, ArgProb: 4.81e-01, Prob: 1.00] A
#
# BEST --> Perf: 1.3491961802695127, e-Sol: [22  2]
# Repeticion:
# 4
# CEC_p1_PID_exp4 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.54e+02 [Initial]
# CEC_p1_PID_exp4 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 3.99e+01, currPerf: 1.54e+02, bestPerf: 1.54e+02 , [Delta: -1.14e+02, ArgProb: 7.35e-03, Prob: 1.00] A+
# CEC_p1_PID_exp4 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 1.71e+02, currPerf: 3.99e+01, bestPerf: 3.99e+01 , [Delta: 1.31e+02, ArgProb: -1.70e-02, Prob: 0.98] A
# CEC_p1_PID_exp4 :: Step:    3, Action: Roll        , Temp: 3.33e+01, Card:   2, candPerf: 2.02e+02, currPerf: 1.71e+02, bestPerf: 3.99e+01 , [Delta: 3.06e+01, ArgProb: -5.93e-03, Prob: 0.99] A
# CEC_p1_PID_exp4 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 2.94e+02, currPerf: 2.02e+02, bestPerf: 3.99e+01 , [Delta: 9.26e+01, ArgProb: -2.40e-02, Prob: 0.98] A
# CEC_p1_PID_exp4 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   2, candPerf: 3.33e+02, currPerf: 2.94e+02, bestPerf: 3.99e+01 , [Delta: 3.86e+01, ArgProb: -1.25e-02, Prob: 0.99] A
#
# BEST --> Perf: 39.94798267180367, e-Sol: [14  6]
# Repeticion:
# 5
# CEC_p1_PID_exp5 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.23e+01 [Initial]
# CEC_p1_PID_exp5 :: Step:    1, Action: LocalShift  , Temp: 1.00e+02, Card:   2, candPerf: 1.68e+01, currPerf: 1.23e+01, bestPerf: 1.23e+01 , [Delta: 4.54e+00, ArgProb: -3.42e-03, Prob: 1.00] A
# CEC_p1_PID_exp5 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 2.63e+01, currPerf: 1.68e+01, bestPerf: 1.23e+01 , [Delta: 9.50e+00, ArgProb: -1.43e-02, Prob: 0.99] A
# CEC_p1_PID_exp5 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 4.51e+00, currPerf: 2.63e+01, bestPerf: 1.23e+01 , [Delta: -2.18e+01, ArgProb: 4.93e-02, Prob: 1.00] A+
# CEC_p1_PID_exp5 :: Step:    4, Action: RollMany    , Temp: 2.50e+01, Card:   2, candPerf: 7.13e+00, currPerf: 4.51e+00, bestPerf: 4.51e+00 , [Delta: 2.62e+00, ArgProb: -7.90e-03, Prob: 0.99] A
# CEC_p1_PID_exp5 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   2, candPerf: 5.47e+00, currPerf: 7.13e+00, bestPerf: 4.51e+00 , [Delta: -1.66e+00, ArgProb: 6.26e-03, Prob: 1.00] A
# CEC_p1_PID_exp5 :: Step:    6, Action: Restart     , Temp: 1.67e+01, Card:   2, candPerf: 3.91e+00, currPerf: 5.47e+00, bestPerf: 4.51e+00 , [Delta: -1.56e+00, ArgProb: 7.05e-03, Prob: 1.00] A+
# CEC_p1_PID_exp5 :: Step:    7, Action: Add         , Temp: 1.43e+01, Card:   3, candPerf: 1.78e+01, currPerf: 3.91e+00, bestPerf: 3.91e+00 , [Delta: 1.39e+01, ArgProb: -7.35e-02, Prob: 0.93] A
# CEC_p1_PID_exp5 :: Step:    8, Action: Shift       , Temp: 1.25e+01, Card:   3, candPerf: 1.42e+01, currPerf: 1.78e+01, bestPerf: 3.91e+00 , [Delta: -3.64e+00, ArgProb: 2.20e-02, Prob: 1.00] A
# CEC_p1_PID_exp5 :: Step:    9, Action: Swap        , Temp: 1.11e+01, Card:   3, candPerf: 2.04e+01, currPerf: 1.42e+01, bestPerf: 3.91e+00 , [Delta: 6.23e+00, ArgProb: -4.23e-02, Prob: 0.96] A
# CEC_p1_PID_exp5 :: Step:   10, Action: Restart     , Temp: 1.00e+01, Card:   3, candPerf: 1.37e+00, currPerf: 2.04e+01, bestPerf: 3.91e+00 , [Delta: -1.91e+01, ArgProb: 1.44e-01, Prob: 1.00] A+
#
# BEST --> Perf: 1.3736012693589428, e-Sol: [12 17 22]
# Repeticion:
# 6
# CEC_p1_PID_exp6 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 4.42e+00 [Initial]
# CEC_p1_PID_exp6 :: Step:    1, Action: LocalShift  , Temp: 1.00e+02, Card:   2, candPerf: 2.05e+00, currPerf: 4.42e+00, bestPerf: 4.42e+00 , [Delta: -2.37e+00, ArgProb: 4.37e-03, Prob: 1.00] A+
# CEC_p1_PID_exp6 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 8.49e+00, currPerf: 2.05e+00, bestPerf: 2.05e+00 , [Delta: 6.44e+00, ArgProb: -2.38e-02, Prob: 0.98] A
# CEC_p1_PID_exp6 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 2.13e+02, currPerf: 8.49e+00, bestPerf: 2.05e+00 , [Delta: 2.04e+02, ArgProb: -1.13e+00, Prob: 0.32]
# CEC_p1_PID_exp6 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 1.21e+01, currPerf: 8.49e+00, bestPerf: 2.05e+00 , [Delta: 3.59e+00, ArgProb: -2.65e-02, Prob: 0.97] A
# CEC_p1_PID_exp6 :: Step:    5, Action: RollMany    , Temp: 2.00e+01, Card:   2, candPerf: 1.22e+01, currPerf: 1.21e+01, bestPerf: 2.05e+00 , [Delta: 1.49e-01, ArgProb: -1.38e-03, Prob: 1.00] A
#
# BEST --> Perf: 2.0534443494367474, e-Sol: [22  6]
# Repeticion:
# 7
# CEC_p1_PID_exp7 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 2.46e+00 [Initial]
# CEC_p1_PID_exp7 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 2.55e+00, currPerf: 2.46e+00, bestPerf: 2.46e+00 , [Delta: 8.98e-02, ArgProb: -2.59e-04, Prob: 1.00] A
# CEC_p1_PID_exp7 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 3.47e+00, currPerf: 2.55e+00, bestPerf: 2.46e+00 , [Delta: 9.21e-01, ArgProb: -5.32e-03, Prob: 0.99] A
# CEC_p1_PID_exp7 :: Step:    3, Action: RollMany    , Temp: 3.33e+01, Card:   2, candPerf: 5.66e+00, currPerf: 3.47e+00, bestPerf: 2.46e+00 , [Delta: 2.19e+00, ArgProb: -1.90e-02, Prob: 0.98] A
# CEC_p1_PID_exp7 :: Step:    4, Action: Roll        , Temp: 2.50e+01, Card:   2, candPerf: 3.63e+00, currPerf: 5.66e+00, bestPerf: 2.46e+00 , [Delta: -2.03e+00, ArgProb: 2.35e-02, Prob: 1.00] A
#
# BEST --> Perf: 2.46151812252745, e-Sol: [5 7]
# Repeticion:
# 8
# CEC_p1_PID_exp8 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 2.68e+00 [Initial]
# CEC_p1_PID_exp8 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 1.51e+00, currPerf: 2.68e+00, bestPerf: 2.68e+00 , [Delta: -1.17e+00, ArgProb: 3.17e-03, Prob: 1.00] A+
# CEC_p1_PID_exp8 :: Step:    2, Action: Restart     , Temp: 5.00e+01, Card:   2, candPerf: 2.47e+00, currPerf: 1.51e+00, bestPerf: 1.51e+00 , [Delta: 9.61e-01, ArgProb: -5.23e-03, Prob: 0.99] A
# CEC_p1_PID_exp8 :: Step:    3, Action: Restart     , Temp: 3.33e+01, Card:   2, candPerf: 2.07e+00, currPerf: 2.47e+00, bestPerf: 1.51e+00 , [Delta: -3.97e-01, ArgProb: 3.24e-03, Prob: 1.00] A
# CEC_p1_PID_exp8 :: Step:    4, Action: Mirror      , Temp: 2.50e+01, Card:   2, candPerf: 2.04e+00, currPerf: 2.07e+00, bestPerf: 1.51e+00 , [Delta: -2.97e-02, ArgProb: 3.23e-04, Prob: 1.00] A
# CEC_p1_PID_exp8 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   2, candPerf: 1.79e+00, currPerf: 2.04e+00, bestPerf: 1.51e+00 , [Delta: -2.51e-01, ArgProb: 3.41e-03, Prob: 1.00] A
#
# BEST --> Perf: 1.5101630689447036, e-Sol: [22  3]
# Repeticion:
# 9
# CEC_p1_PID_exp9 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 3.60e+00 [Initial]
# CEC_p1_PID_exp9 :: Step:    1, Action: Add         , Temp: 1.00e+02, Card:   3, candPerf: 1.39e+00, currPerf: 3.60e+00, bestPerf: 3.60e+00 , [Delta: -2.21e+00, ArgProb: 4.80e-03, Prob: 1.00] A+
# CEC_p1_PID_exp9 :: Step:    2, Action: Restart     , Temp: 5.00e+01, Card:   3, candPerf: 1.08e+01, currPerf: 1.39e+00, bestPerf: 1.39e+00 , [Delta: 9.39e+00, ArgProb: -4.08e-02, Prob: 0.96] A
# CEC_p1_PID_exp9 :: Step:    3, Action: Mirror      , Temp: 3.33e+01, Card:   3, candPerf: 6.26e+00, currPerf: 1.08e+01, bestPerf: 1.39e+00 , [Delta: -4.52e+00, ArgProb: 2.94e-02, Prob: 1.00] A
# CEC_p1_PID_exp9 :: Step:    4, Action: Roll        , Temp: 2.50e+01, Card:   3, candPerf: 8.30e+00, currPerf: 6.26e+00, bestPerf: 1.39e+00 , [Delta: 2.04e+00, ArgProb: -1.77e-02, Prob: 0.98] A
# CEC_p1_PID_exp9 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   3, candPerf: 5.80e+00, currPerf: 8.30e+00, bestPerf: 1.39e+00 , [Delta: -2.51e+00, ArgProb: 2.72e-02, Prob: 1.00] A
#
# BEST --> Perf: 1.394780195704612, e-Sol: [22 23  6]
# Repeticion:
# 10
# CEC_p1_PID_exp10 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 7.65e+01 [Initial]
# CEC_p1_PID_exp10 :: Step:    1, Action: Roll        , Temp: 1.00e+02, Card:   2, candPerf: 8.78e+01, currPerf: 7.65e+01, bestPerf: 7.65e+01 , [Delta: 1.12e+01, ArgProb: -1.45e-03, Prob: 1.00] A
# CEC_p1_PID_exp10 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 1.18e+01, currPerf: 8.78e+01, bestPerf: 7.65e+01 , [Delta: -7.59e+01, ArgProb: 1.96e-02, Prob: 1.00] A+
# CEC_p1_PID_exp10 :: Step:    3, Action: Add         , Temp: 3.33e+01, Card:   3, candPerf: 2.08e+01, currPerf: 1.18e+01, bestPerf: 1.18e+01 , [Delta: 9.02e+00, ArgProb: -3.49e-03, Prob: 1.00] A
# CEC_p1_PID_exp10 :: Step:    4, Action: Shift       , Temp: 2.50e+01, Card:   3, candPerf: 3.22e+02, currPerf: 2.08e+01, bestPerf: 1.18e+01 , [Delta: 3.01e+02, ArgProb: -1.55e-01, Prob: 0.86] A
# CEC_p1_PID_exp10 :: Step:    5, Action: Shift       , Temp: 2.00e+01, Card:   3, candPerf: 4.54e+00, currPerf: 3.22e+02, bestPerf: 1.18e+01 , [Delta: -3.17e+02, ArgProb: 2.05e-01, Prob: 1.00] A+
# CEC_p1_PID_exp10 :: Step:    6, Action: Remove      , Temp: 1.67e+01, Card:   2, candPerf: 7.55e+00, currPerf: 4.54e+00, bestPerf: 4.54e+00 , [Delta: 3.01e+00, ArgProb: -2.33e-03, Prob: 1.00] A
# CEC_p1_PID_exp10 :: Step:    7, Action: Swap        , Temp: 1.43e+01, Card:   2, candPerf: 7.02e+00, currPerf: 7.55e+00, bestPerf: 4.54e+00 , [Delta: -5.33e-01, ArgProb: 4.81e-04, Prob: 1.00] A
# CEC_p1_PID_exp10 :: Step:    8, Action: Swap        , Temp: 1.25e+01, Card:   2, candPerf: 8.02e+00, currPerf: 7.02e+00, bestPerf: 4.54e+00 , [Delta: 1.00e+00, ArgProb: -1.03e-03, Prob: 1.00] A
# CEC_p1_PID_exp10 :: Step:    9, Action: Restart     , Temp: 1.11e+01, Card:   2, candPerf: 5.25e+00, currPerf: 8.02e+00, bestPerf: 4.54e+00 , [Delta: -2.77e+00, ArgProb: 3.21e-03, Prob: 1.00] A
#
# BEST --> Perf: 4.539202450862701, e-Sol: [12 15 14]
# Repeticion:
# 11
# CEC_p1_PID_exp11 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 7.18e+00 [Initial]
# CEC_p1_PID_exp11 :: Step:    1, Action: Swap        , Temp: 1.00e+02, Card:   2, candPerf: 3.21e+00, currPerf: 7.18e+00, bestPerf: 7.18e+00 , [Delta: -3.97e+00, ArgProb: 4.85e-03, Prob: 1.00] A+
# CEC_p1_PID_exp11 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 4.96e+00, currPerf: 3.21e+00, bestPerf: 3.21e+00 , [Delta: 1.75e+00, ArgProb: -4.28e-03, Prob: 1.00] A
# CEC_p1_PID_exp11 :: Step:    3, Action: Restart     , Temp: 3.33e+01, Card:   2, candPerf: 3.50e+01, currPerf: 4.96e+00, bestPerf: 3.21e+00 , [Delta: 3.00e+01, ArgProb: -1.10e-01, Prob: 0.90] A
# CEC_p1_PID_exp11 :: Step:    4, Action: Roll        , Temp: 2.50e+01, Card:   2, candPerf: 3.41e+02, currPerf: 3.50e+01, bestPerf: 3.21e+00 , [Delta: 3.06e+02, ArgProb: -1.50e+00, Prob: 0.22] A
# CEC_p1_PID_exp11 :: Step:    5, Action: RollMany    , Temp: 2.00e+01, Card:   2, candPerf: 1.38e+02, currPerf: 3.41e+02, bestPerf: 3.21e+00 , [Delta: -2.03e+02, ArgProb: 1.24e+00, Prob: 1.00] A
#
# BEST --> Perf: 3.210689962841363, e-Sol: [12 11]
# Repeticion:
# 12
# CEC_p1_PID_exp12 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.13e+01 [Initial]
# CEC_p1_PID_exp12 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 7.28e+00, currPerf: 1.13e+01, bestPerf: 1.13e+01 , [Delta: -4.03e+00, ArgProb: 3.28e-03, Prob: 1.00] A+
# CEC_p1_PID_exp12 :: Step:    2, Action: Add         , Temp: 5.00e+01, Card:   3, candPerf: 3.60e+00, currPerf: 7.28e+00, bestPerf: 7.28e+00 , [Delta: -3.68e+00, ArgProb: 5.97e-03, Prob: 1.00] A+
# CEC_p1_PID_exp12 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   3, candPerf: 4.09e+00, currPerf: 3.60e+00, bestPerf: 3.60e+00 , [Delta: 4.83e-01, ArgProb: -1.18e-03, Prob: 1.00] A
# CEC_p1_PID_exp12 :: Step:    4, Action: Remove      , Temp: 2.50e+01, Card:   2, candPerf: 3.01e+00, currPerf: 4.09e+00, bestPerf: 3.60e+00 , [Delta: -1.08e+00, ArgProb: 3.52e-03, Prob: 1.00] A+
# CEC_p1_PID_exp12 :: Step:    5, Action: Add         , Temp: 2.00e+01, Card:   3, candPerf: 2.25e+00, currPerf: 3.01e+00, bestPerf: 3.01e+00 , [Delta: -7.55e-01, ArgProb: 3.07e-03, Prob: 1.00] A+
# CEC_p1_PID_exp12 :: Step:    6, Action: Restart     , Temp: 1.67e+01, Card:   3, candPerf: 1.14e+02, currPerf: 2.25e+00, bestPerf: 2.25e+00 , [Delta: 1.11e+02, ArgProb: -5.42e-01, Prob: 0.58] A
# CEC_p1_PID_exp12 :: Step:    7, Action: Mirror      , Temp: 1.43e+01, Card:   3, candPerf: 1.05e+02, currPerf: 1.14e+02, bestPerf: 2.25e+00 , [Delta: -8.33e+00, ArgProb: 4.74e-02, Prob: 1.00] A
# CEC_p1_PID_exp12 :: Step:    8, Action: RollMany    , Temp: 1.25e+01, Card:   3, candPerf: 1.13e+02, currPerf: 1.05e+02, bestPerf: 2.25e+00 , [Delta: 7.83e+00, ArgProb: -5.09e-02, Prob: 0.95] A
# CEC_p1_PID_exp12 :: Step:    9, Action: RollMany    , Temp: 1.11e+01, Card:   3, candPerf: 3.60e+02, currPerf: 1.13e+02, bestPerf: 2.25e+00 , [Delta: 2.47e+02, ArgProb: -1.81e+00, Prob: 0.16]
#
# BEST --> Perf: 2.249747256742654, e-Sol: [11 22 17]
# Repeticion:
# 13
# CEC_p1_PID_exp13 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 4.82e+00 [Initial]
# CEC_p1_PID_exp13 :: Step:    1, Action: Shift       , Temp: 1.00e+02, Card:   2, candPerf: 3.59e+00, currPerf: 4.82e+00, bestPerf: 4.82e+00 , [Delta: -1.23e+00, ArgProb: 2.11e-03, Prob: 1.00] A+
# CEC_p1_PID_exp13 :: Step:    2, Action: Roll        , Temp: 5.00e+01, Card:   2, candPerf: 2.59e+00, currPerf: 3.59e+00, bestPerf: 3.59e+00 , [Delta: -9.96e-01, ArgProb: 3.42e-03, Prob: 1.00] A+
# CEC_p1_PID_exp13 :: Step:    3, Action: Add         , Temp: 3.33e+01, Card:   3, candPerf: 8.09e+00, currPerf: 2.59e+00, bestPerf: 2.59e+00 , [Delta: 5.50e+00, ArgProb: -2.83e-02, Prob: 0.97] A
# CEC_p1_PID_exp13 :: Step:    4, Action: Remove      , Temp: 2.50e+01, Card:   2, candPerf: 3.00e+00, currPerf: 8.09e+00, bestPerf: 2.59e+00 , [Delta: -5.10e+00, ArgProb: 3.50e-02, Prob: 1.00] A
# CEC_p1_PID_exp13 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   2, candPerf: 4.40e+00, currPerf: 3.00e+00, bestPerf: 2.59e+00 , [Delta: 1.41e+00, ArgProb: -1.21e-02, Prob: 0.99] A
# CEC_p1_PID_exp13 :: Step:    6, Action: Shift       , Temp: 1.67e+01, Card:   2, candPerf: 6.95e+00, currPerf: 4.40e+00, bestPerf: 2.59e+00 , [Delta: 2.55e+00, ArgProb: -2.63e-02, Prob: 0.97] A
#
# BEST --> Perf: 2.594112256960323, e-Sol: [18  5]
# Repeticion:
# 14
# CEC_p1_PID_exp14 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.83e+02 [Initial]
# CEC_p1_PID_exp14 :: Step:    1, Action: Swap        , Temp: 1.00e+02, Card:   2, candPerf: 1.59e+02, currPerf: 1.83e+02, bestPerf: 1.83e+02 , [Delta: -2.46e+01, ArgProb: 1.33e-03, Prob: 1.00] A+
# CEC_p1_PID_exp14 :: Step:    2, Action: Mirror      , Temp: 5.00e+01, Card:   2, candPerf: 1.33e+02, currPerf: 1.59e+02, bestPerf: 1.59e+02 , [Delta: -2.59e+01, ArgProb: 2.82e-03, Prob: 1.00] A+
# CEC_p1_PID_exp14 :: Step:    3, Action: RollMany    , Temp: 3.33e+01, Card:   2, candPerf: 6.91e+01, currPerf: 1.33e+02, bestPerf: 1.33e+02 , [Delta: -6.36e+01, ArgProb: 1.04e-02, Prob: 1.00] A+
# CEC_p1_PID_exp14 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 2.94e+00, currPerf: 6.91e+01, bestPerf: 6.91e+01 , [Delta: -6.62e+01, ArgProb: 1.44e-02, Prob: 1.00] A+
# CEC_p1_PID_exp14 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   3, candPerf: 3.28e+00, currPerf: 2.94e+00, bestPerf: 2.94e+00 , [Delta: 3.44e-01, ArgProb: -9.33e-05, Prob: 1.00] A
# CEC_p1_PID_exp14 :: Step:    6, Action: Restart     , Temp: 1.67e+01, Card:   3, candPerf: 2.97e+00, currPerf: 3.28e+00, bestPerf: 2.94e+00 , [Delta: -3.11e-01, ArgProb: 1.01e-04, Prob: 1.00] A
# CEC_p1_PID_exp14 :: Step:    7, Action: Roll        , Temp: 1.43e+01, Card:   3, candPerf: 9.17e+00, currPerf: 2.97e+00, bestPerf: 2.94e+00 , [Delta: 6.20e+00, ArgProb: -2.35e-03, Prob: 1.00] A
# CEC_p1_PID_exp14 :: Step:    8, Action: Restart     , Temp: 1.25e+01, Card:   3, candPerf: 6.17e+00, currPerf: 9.17e+00, bestPerf: 2.94e+00 , [Delta: -3.00e+00, ArgProb: 1.30e-03, Prob: 1.00] A
#
# BEST --> Perf: 2.935289084593271, e-Sol: [19 11 12]
# Repeticion:
# 15
# CEC_p1_PID_exp15 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 5.43e+00 [Initial]
# CEC_p1_PID_exp15 :: Step:    1, Action: Roll        , Temp: 1.00e+02, Card:   2, candPerf: 8.82e+00, currPerf: 5.43e+00, bestPerf: 5.43e+00 , [Delta: 3.39e+00, ArgProb: -5.26e-03, Prob: 0.99] A
# CEC_p1_PID_exp15 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 2.03e+00, currPerf: 8.82e+00, bestPerf: 5.43e+00 , [Delta: -6.79e+00, ArgProb: 2.11e-02, Prob: 1.00] A+
# CEC_p1_PID_exp15 :: Step:    3, Action: Add         , Temp: 3.33e+01, Card:   3, candPerf: 7.57e+00, currPerf: 2.03e+00, bestPerf: 2.03e+00 , [Delta: 5.54e+00, ArgProb: -2.58e-02, Prob: 0.97] A
# CEC_p1_PID_exp15 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   3, candPerf: 5.00e+00, currPerf: 7.57e+00, bestPerf: 2.03e+00 , [Delta: -2.57e+00, ArgProb: 1.60e-02, Prob: 1.00] A
# CEC_p1_PID_exp15 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   3, candPerf: 4.47e+00, currPerf: 5.00e+00, bestPerf: 2.03e+00 , [Delta: -5.25e-01, ArgProb: 4.08e-03, Prob: 1.00] A
# CEC_p1_PID_exp15 :: Step:    6, Action: Mirror      , Temp: 1.67e+01, Card:   3, candPerf: 1.53e+01, currPerf: 4.47e+00, bestPerf: 2.03e+00 , [Delta: 1.09e+01, ArgProb: -1.01e-01, Prob: 0.90] A
#
# BEST --> Perf: 2.027711816111835, e-Sol: [13 20]
# Repeticion:
# 16
# CEC_p1_PID_exp16 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.41e+01 [Initial]
# CEC_p1_PID_exp16 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 1.66e+01, currPerf: 1.41e+01, bestPerf: 1.41e+01 , [Delta: 2.49e+00, ArgProb: -1.64e-03, Prob: 1.00] A
# CEC_p1_PID_exp16 :: Step:    2, Action: RollMany    , Temp: 5.00e+01, Card:   2, candPerf: 5.32e+01, currPerf: 1.66e+01, bestPerf: 1.41e+01 , [Delta: 3.66e+01, ArgProb: -4.83e-02, Prob: 0.95] A
# CEC_p1_PID_exp16 :: Step:    3, Action: Add         , Temp: 3.33e+01, Card:   3, candPerf: 3.06e+00, currPerf: 5.32e+01, bestPerf: 1.41e+01 , [Delta: -5.01e+01, ArgProb: 9.93e-02, Prob: 1.00] A+
# CEC_p1_PID_exp16 :: Step:    4, Action: Mirror      , Temp: 2.50e+01, Card:   3, candPerf: 5.85e+00, currPerf: 3.06e+00, bestPerf: 3.06e+00 , [Delta: 2.79e+00, ArgProb: -7.36e-03, Prob: 0.99] A
# CEC_p1_PID_exp16 :: Step:    5, Action: Restart     , Temp: 2.00e+01, Card:   3, candPerf: 3.56e+02, currPerf: 5.85e+00, bestPerf: 3.06e+00 , [Delta: 3.50e+02, ArgProb: -1.16e+00, Prob: 0.32] A
# CEC_p1_PID_exp16 :: Step:    6, Action: Mirror      , Temp: 1.67e+01, Card:   3, candPerf: 1.34e+02, currPerf: 3.56e+02, bestPerf: 3.06e+00 , [Delta: -2.22e+02, ArgProb: 8.80e-01, Prob: 1.00] A
# CEC_p1_PID_exp16 :: Step:    7, Action: Roll        , Temp: 1.43e+01, Card:   3, candPerf: 1.16e+02, currPerf: 1.34e+02, bestPerf: 3.06e+00 , [Delta: -1.77e+01, ArgProb: 8.17e-02, Prob: 1.00] A
#
# BEST --> Perf: 3.062991008233589, e-Sol: [21 18 14]
# Repeticion:
# 17
# CEC_p1_PID_exp17 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 3.53e+01 [Initial]
# CEC_p1_PID_exp17 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 1.40e+01, currPerf: 3.53e+01, bestPerf: 3.53e+01 , [Delta: -2.13e+01, ArgProb: 5.86e-03, Prob: 1.00] A+
# CEC_p1_PID_exp17 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 1.77e+01, currPerf: 1.40e+01, bestPerf: 1.40e+01 , [Delta: 3.66e+00, ArgProb: -2.02e-03, Prob: 1.00] A
# CEC_p1_PID_exp17 :: Step:    3, Action: Restart     , Temp: 3.33e+01, Card:   2, candPerf: 6.63e+00, currPerf: 1.77e+01, bestPerf: 1.40e+01 , [Delta: -1.10e+01, ArgProb: 9.13e-03, Prob: 1.00] A+
# CEC_p1_PID_exp17 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 9.32e+00, currPerf: 6.63e+00, bestPerf: 6.63e+00 , [Delta: 2.69e+00, ArgProb: -2.97e-03, Prob: 1.00] A
# CEC_p1_PID_exp17 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   2, candPerf: 6.30e+00, currPerf: 9.32e+00, bestPerf: 6.63e+00 , [Delta: -3.02e+00, ArgProb: 4.16e-03, Prob: 1.00] A+
# CEC_p1_PID_exp17 :: Step:    6, Action: RollMany    , Temp: 1.67e+01, Card:   2, candPerf: 6.53e+00, currPerf: 6.30e+00, bestPerf: 6.30e+00 , [Delta: 2.29e-01, ArgProb: -3.78e-04, Prob: 1.00] A
# CEC_p1_PID_exp17 :: Step:    7, Action: LocalShift  , Temp: 1.43e+01, Card:   2, candPerf: 1.60e+01, currPerf: 6.53e+00, bestPerf: 6.30e+00 , [Delta: 9.45e+00, ArgProb: -1.82e-02, Prob: 0.98] A
# CEC_p1_PID_exp17 :: Step:    8, Action: Roll        , Temp: 1.25e+01, Card:   2, candPerf: 1.28e+01, currPerf: 1.60e+01, bestPerf: 6.30e+00 , [Delta: -3.21e+00, ArgProb: 7.07e-03, Prob: 1.00] A
# CEC_p1_PID_exp17 :: Step:    9, Action: Roll        , Temp: 1.11e+01, Card:   2, candPerf: 6.56e+00, currPerf: 1.28e+01, bestPerf: 6.30e+00 , [Delta: -6.20e+00, ArgProb: 1.54e-02, Prob: 1.00] A
#
# BEST --> Perf: 6.3008431688643025, e-Sol: [8 3]
# Repeticion:
# 18
# CEC_p1_PID_exp18 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.59e+01 [Initial]
# CEC_p1_PID_exp18 :: Step:    1, Action: Add         , Temp: 1.00e+02, Card:   3, candPerf: 8.76e+00, currPerf: 1.59e+01, bestPerf: 1.59e+01 , [Delta: -7.15e+00, ArgProb: 4.23e-03, Prob: 1.00] A+
# CEC_p1_PID_exp18 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   3, candPerf: 1.49e+01, currPerf: 8.76e+00, bestPerf: 8.76e+00 , [Delta: 6.11e+00, ArgProb: -7.23e-03, Prob: 0.99] A
# CEC_p1_PID_exp18 :: Step:    3, Action: Swap        , Temp: 3.33e+01, Card:   3, candPerf: 1.67e+01, currPerf: 1.49e+01, bestPerf: 8.76e+00 , [Delta: 1.87e+00, ArgProb: -3.32e-03, Prob: 1.00] A
# CEC_p1_PID_exp18 :: Step:    4, Action: Shift       , Temp: 2.50e+01, Card:   3, candPerf: 5.32e+00, currPerf: 1.67e+01, bestPerf: 8.76e+00 , [Delta: -1.14e+01, ArgProb: 2.70e-02, Prob: 1.00] A+
# CEC_p1_PID_exp18 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   3, candPerf: 6.54e+00, currPerf: 5.32e+00, bestPerf: 5.32e+00 , [Delta: 1.21e+00, ArgProb: -3.59e-03, Prob: 1.00] A
# CEC_p1_PID_exp18 :: Step:    6, Action: LocalShift  , Temp: 1.67e+01, Card:   3, candPerf: 1.99e+00, currPerf: 6.54e+00, bestPerf: 5.32e+00 , [Delta: -4.55e+00, ArgProb: 1.61e-02, Prob: 1.00] A+
# CEC_p1_PID_exp18 :: Step:    7, Action: Swap        , Temp: 1.43e+01, Card:   3, candPerf: 3.09e+00, currPerf: 1.99e+00, bestPerf: 1.99e+00 , [Delta: 1.10e+00, ArgProb: -4.57e-03, Prob: 1.00] A
# CEC_p1_PID_exp18 :: Step:    8, Action: Restart     , Temp: 1.25e+01, Card:   3, candPerf: 1.41e+00, currPerf: 3.09e+00, bestPerf: 1.99e+00 , [Delta: -1.68e+00, ArgProb: 7.94e-03, Prob: 1.00] A+
# CEC_p1_PID_exp18 :: Step:    9, Action: Shift       , Temp: 1.11e+01, Card:   3, candPerf: 2.47e+00, currPerf: 1.41e+00, bestPerf: 1.41e+00 , [Delta: 1.06e+00, ArgProb: -5.63e-03, Prob: 0.99] A
# CEC_p1_PID_exp18 :: Step:   10, Action: LocalShift  , Temp: 1.00e+01, Card:   3, candPerf: 2.39e+00, currPerf: 2.47e+00, bestPerf: 1.41e+00 , [Delta: -7.91e-02, ArgProb: 4.68e-04, Prob: 1.00] A
#
# BEST --> Perf: 1.4139307498618754, e-Sol: [21 23 17]
# Repeticion:
# 19
# CEC_p1_PID_exp19 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.94e+01 [Initial]
# CEC_p1_PID_exp19 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 1.00e+01, currPerf: 1.94e+01, bestPerf: 1.94e+01 , [Delta: -9.40e+00, ArgProb: 4.60e-03, Prob: 1.00] A+
# CEC_p1_PID_exp19 :: Step:    2, Action: Add         , Temp: 5.00e+01, Card:   3, candPerf: 2.17e+00, currPerf: 1.00e+01, bestPerf: 1.00e+01 , [Delta: -7.87e+00, ArgProb: 7.70e-03, Prob: 1.00] A+
# CEC_p1_PID_exp19 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   3, candPerf: 5.36e+00, currPerf: 2.17e+00, bestPerf: 2.17e+00 , [Delta: 3.19e+00, ArgProb: -4.68e-03, Prob: 1.00] A
# CEC_p1_PID_exp19 :: Step:    4, Action: Mirror      , Temp: 2.50e+01, Card:   3, candPerf: 3.15e+00, currPerf: 5.36e+00, bestPerf: 2.17e+00 , [Delta: -2.22e+00, ArgProb: 4.34e-03, Prob: 1.00] A
# CEC_p1_PID_exp19 :: Step:    5, Action: Shift       , Temp: 2.00e+01, Card:   3, candPerf: 1.29e+01, currPerf: 3.15e+00, bestPerf: 2.17e+00 , [Delta: 9.79e+00, ArgProb: -2.39e-02, Prob: 0.98] A
# CEC_p1_PID_exp19 :: Step:    6, Action: Swap        , Temp: 1.67e+01, Card:   3, candPerf: 7.71e+00, currPerf: 1.29e+01, bestPerf: 2.17e+00 , [Delta: -5.22e+00, ArgProb: 1.53e-02, Prob: 1.00] A
#
# BEST --> Perf: 2.1717234192536816, e-Sol: [17 10 22]
