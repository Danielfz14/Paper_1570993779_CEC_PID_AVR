# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
import numpy as np
import pandas as pd

import customhys as mh
from customhys import metaheuristic as mh
from customhys import benchmark_func as bf
from customhys import hyperheuristic as hh
import numpy as np
import matplotlib.pyplot as plt

import control as co
import numpy as np
from control.matlab import *
import matplotlib.pyplot as plt
from scipy.integrate import simps
import matlab.engine 
eng=matlab.engine.start_matlab()
eng = matlab.engine.start_matlab("-desktop")
# Out:
# benchmark_func.py:29: ImportWarning: `optproblems` not found! Please, install it to use the cec2005 benchmark functions

# %%
class P1(bf.BasicProblem):
    def __init__(self, variable_num):
        super().__init__(variable_num)
        self.max_search_range =np.array([1.5, 1.5, 1.0 ,0.5 ])                    
        self.min_search_range = np.array([0.000001, 0.0000001,0.0000001,0.0000001]) 
        self.global_optimum_solution = 0.0
    def get_func_val(self, variables, *args):
        fcost=eng.AVR_PIDD_CEC_p1(float(variables[0]),float(variables[1]),float(variables[2]),float(variables[3]))
        return fcost

# %%
best_solutions = []
perf= []
hist_curr1= []
hist_best1= []

parameters = dict(
    cardinality=3,  # Max. numb. of SOs in MHs, lvl:1
    cardinality_min=2,  # Min. numb. of SOs in MHs, lvl:1
    num_iterations=15,  # Iterations a MH performs, lvl:1
    num_agents=10,  # Agents in population,     lvl:1
    as_mh=True,  # HH sequence as a MH?,     lvl:2
    num_replicas=10,  # Replicas per each MH,     lvl:2
    num_steps=10,  # Trials per HH step,       lvl:2
    stagnation_percentage=0.37,  # Stagnation percentage,    lvl:2
    max_temperature=100,  # Initial temperature (SA), lvl:2
    min_temperature=1e-6,  # Min temperature (SA),     lvl:2
    cooling_rate=1e-3,  # Cooling rate (SA),        lvl:2
    temperature_scheme='fast',  # Temperature updating (SA),lvl:2
    acceptance_scheme='exponential',  # Acceptance mode,          lvl:2
    allow_weight_matrix=True,  # Weight matrix,            lvl:2
    trial_overflow=False,  # Trial overflow policy,    lvl:2
    learnt_dataset=None,  # If it is a learnt dataset related with the heuristic space
    repeat_operators=True,  # Allow repeating SOs inSeq,lvl:2
    verbose=True,  # Verbose process,          lvl:2
    learning_portion=0.37,  # Percent of seqs to learn  lvl:2
    solver='static')  # Indicate which solver use lvl:1

heuristic_space="short_collection2.txt"

with open('C:/Users/A00836756/AppData/Local/anaconda3/Lib/site-packages/customhys/collections/' + heuristic_space, 'r', encoding='utf-8') as operators_file:
    heuristic_space_list = [eval(line.rstrip('\n')) for line in operators_file]
for i in range(1, 20):
    print("Repeticion:")
    print(i)
    fun = P1(3)
    prob = fun. get_formatted_problem ()
    file_label1 = f'1CEC_p1_PIDD2_exp{i}'
    hyp = hh.Hyperheuristic(heuristic_space_list,problem=prob, parameters=parameters, file_label=file_label1)
    best_sol, best_perf, hist_curr, hist_best =hyp.solve()
    #search_operators = hyp.get_operators(best_sol)
    #print(search_operators)
    best_solutions.append(best_sol)
    perf.append(best_perf)
    hist_curr1.append(hist_curr)
    hist_best1.append(hist_best)
# Out:
# Repeticion:
# 1
# 1CEC_p1_PIDD2_exp1 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 3.03e+02 [Initial]
# 1CEC_p1_PIDD2_exp1 :: Step:    1, Action: Restart     , Temp: 1.00e+02, Card:   2, candPerf: 1.72e+00, currPerf: 3.03e+02, bestPerf: 3.03e+02 , [Delta: -3.02e+02, ArgProb: 9.91e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp1 :: Step:    2, Action: Roll        , Temp: 5.00e+01, Card:   2, candPerf: 2.53e+00, currPerf: 1.72e+00, bestPerf: 1.72e+00 , [Delta: 8.10e-01, ArgProb: -5.32e-05, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp1 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 3.49e+01, currPerf: 2.53e+00, bestPerf: 1.72e+00 , [Delta: 3.24e+01, ArgProb: -3.20e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp1 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 6.95e+00, currPerf: 3.49e+01, bestPerf: 1.72e+00 , [Delta: -2.80e+01, ArgProb: 3.68e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp1 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   3, candPerf: 1.62e+00, currPerf: 6.95e+00, bestPerf: 1.72e+00 , [Delta: -5.33e+00, ArgProb: 8.76e-04, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp1 :: Step:    6, Action: Shift       , Temp: 1.67e+01, Card:   3, candPerf: 9.67e+00, currPerf: 1.62e+00, bestPerf: 1.62e+00 , [Delta: 8.04e+00, ArgProb: -1.59e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp1 :: Step:    7, Action: Swap        , Temp: 1.43e+01, Card:   3, candPerf: 3.10e+01, currPerf: 9.67e+00, bestPerf: 1.62e+00 , [Delta: 2.13e+01, ArgProb: -4.90e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp1 :: Step:    8, Action: Roll        , Temp: 1.25e+01, Card:   3, candPerf: 9.38e+01, currPerf: 3.10e+01, bestPerf: 1.62e+00 , [Delta: 6.28e+01, ArgProb: -1.65e-02, Prob: 0.98] A
# 1CEC_p1_PIDD2_exp1 :: Step:    9, Action: Remove      , Temp: 1.11e+01, Card:   2, candPerf: 7.28e+00, currPerf: 9.38e+01, bestPerf: 1.62e+00 , [Delta: -8.65e+01, ArgProb: 2.56e-02, Prob: 1.00] A
#
# BEST --> Perf: 1.6246046883923164, e-Sol: [23  5 19]
# Repeticion:
# 2
# 1CEC_p1_PIDD2_exp2 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 2.34e+01 [Initial]
# 1CEC_p1_PIDD2_exp2 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 3.71e+01, currPerf: 2.34e+01, bestPerf: 2.34e+01 , [Delta: 1.37e+01, ArgProb: -5.61e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp2 :: Step:    2, Action: Add         , Temp: 5.00e+01, Card:   3, candPerf: 4.64e+00, currPerf: 3.71e+01, bestPerf: 2.34e+01 , [Delta: -3.24e+01, ArgProb: 2.66e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp2 :: Step:    3, Action: Shift       , Temp: 3.33e+01, Card:   3, candPerf: 1.05e+01, currPerf: 4.64e+00, bestPerf: 4.64e+00 , [Delta: 5.83e+00, ArgProb: -7.17e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp2 :: Step:    4, Action: Mirror      , Temp: 2.50e+01, Card:   3, candPerf: 8.37e+00, currPerf: 1.05e+01, bestPerf: 4.64e+00 , [Delta: -2.10e+00, ArgProb: 3.44e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp2 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   3, candPerf: 3.01e+01, currPerf: 8.37e+00, bestPerf: 4.64e+00 , [Delta: 2.17e+01, ArgProb: -4.45e-02, Prob: 0.96]
# 1CEC_p1_PIDD2_exp2 :: Step:    6, Action: Roll        , Temp: 1.67e+01, Card:   3, candPerf: 1.62e+01, currPerf: 8.37e+00, bestPerf: 4.64e+00 , [Delta: 7.79e+00, ArgProb: -1.92e-02, Prob: 0.98] A
#
# BEST --> Perf: 4.643051231674427, e-Sol: [ 4 15  2]
# Repeticion:
# 3
# 1CEC_p1_PIDD2_exp3 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 7.12e+02 [Initial]
# 1CEC_p1_PIDD2_exp3 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 4.30e+02, currPerf: 7.12e+02, bestPerf: 7.12e+02 , [Delta: -2.82e+02, ArgProb: 3.96e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp3 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 3.43e+02, currPerf: 4.30e+02, bestPerf: 4.30e+02 , [Delta: -8.66e+01, ArgProb: 2.43e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp3 :: Step:    3, Action: Shift       , Temp: 3.33e+01, Card:   2, candPerf: 2.34e+02, currPerf: 3.43e+02, bestPerf: 3.43e+02 , [Delta: -1.10e+02, ArgProb: 4.61e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp3 :: Step:    4, Action: Roll        , Temp: 2.50e+01, Card:   2, candPerf: 3.52e+02, currPerf: 2.34e+02, bestPerf: 2.34e+02 , [Delta: 1.19e+02, ArgProb: -6.66e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp3 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   2, candPerf: 1.57e+02, currPerf: 3.52e+02, bestPerf: 2.34e+02 , [Delta: -1.96e+02, ArgProb: 1.37e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp3 :: Step:    6, Action: Roll        , Temp: 1.67e+01, Card:   2, candPerf: 1.15e+02, currPerf: 1.57e+02, bestPerf: 1.57e+02 , [Delta: -4.18e+01, ArgProb: 3.52e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp3 :: Step:    7, Action: Roll        , Temp: 1.43e+01, Card:   2, candPerf: 3.68e+02, currPerf: 1.15e+02, bestPerf: 1.15e+02 , [Delta: 2.53e+02, ArgProb: -2.48e-02, Prob: 0.98] A
# 1CEC_p1_PIDD2_exp3 :: Step:    8, Action: Restart     , Temp: 1.25e+01, Card:   2, candPerf: 1.40e+02, currPerf: 3.68e+02, bestPerf: 1.15e+02 , [Delta: -2.28e+02, ArgProb: 2.56e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp3 :: Step:    9, Action: Shift       , Temp: 1.11e+01, Card:   2, candPerf: 1.09e+01, currPerf: 1.40e+02, bestPerf: 1.15e+02 , [Delta: -1.29e+02, ArgProb: 1.63e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp3 :: Step:   10, Action: Restart     , Temp: 1.00e+01, Card:   2, candPerf: 3.52e+01, currPerf: 1.09e+01, bestPerf: 1.09e+01 , [Delta: 2.43e+01, ArgProb: -3.42e-03, Prob: 1.00] A
#
# BEST --> Perf: 10.892706680480662, e-Sol: [18 17]
# Repeticion:
# 4
# 1CEC_p1_PIDD2_exp4 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 6.41e+01 [Initial]
# 1CEC_p1_PIDD2_exp4 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 3.24e+02, currPerf: 6.41e+01, bestPerf: 6.41e+01 , [Delta: 2.59e+02, ArgProb: -3.99e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp4 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 2.09e+02, currPerf: 3.24e+02, bestPerf: 6.41e+01 , [Delta: -1.14e+02, ArgProb: 3.51e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp4 :: Step:    3, Action: Add         , Temp: 3.33e+01, Card:   3, candPerf: 2.96e+02, currPerf: 2.09e+02, bestPerf: 6.41e+01 , [Delta: 8.70e+01, ArgProb: -4.01e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp4 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   3, candPerf: 2.38e+01, currPerf: 2.96e+02, bestPerf: 6.41e+01 , [Delta: -2.73e+02, ArgProb: 1.67e-01, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp4 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   3, candPerf: 1.55e+01, currPerf: 2.38e+01, bestPerf: 2.38e+01 , [Delta: -8.37e+00, ArgProb: 6.43e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp4 :: Step:    6, Action: RollMany    , Temp: 1.67e+01, Card:   3, candPerf: 5.76e+01, currPerf: 1.55e+01, bestPerf: 1.55e+01 , [Delta: 4.21e+01, ArgProb: -3.88e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp4 :: Step:    7, Action: Swap        , Temp: 1.43e+01, Card:   3, candPerf: 1.40e+01, currPerf: 5.76e+01, bestPerf: 1.55e+01 , [Delta: -4.35e+01, ArgProb: 4.68e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp4 :: Step:    8, Action: Shift       , Temp: 1.25e+01, Card:   3, candPerf: 4.49e+01, currPerf: 1.40e+01, bestPerf: 1.40e+01 , [Delta: 3.08e+01, ArgProb: -3.79e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp4 :: Step:    9, Action: Restart     , Temp: 1.11e+01, Card:   3, candPerf: 1.98e+00, currPerf: 4.49e+01, bestPerf: 1.40e+01 , [Delta: -4.29e+01, ArgProb: 5.93e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp4 :: Step:   10, Action: RollMany    , Temp: 1.00e+01, Card:   3, candPerf: 2.59e+00, currPerf: 1.98e+00, bestPerf: 1.98e+00 , [Delta: 6.18e-01, ArgProb: -9.49e-04, Prob: 1.00] A
#
# BEST --> Perf: 1.9751262728535497, e-Sol: [2 3 9]
# Repeticion:
# 5
# 1CEC_p1_PIDD2_exp5 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.28e+01 [Initial]
# 1CEC_p1_PIDD2_exp5 :: Step:    1, Action: Roll        , Temp: 1.00e+02, Card:   2, candPerf: 4.85e+00, currPerf: 1.28e+01, bestPerf: 1.28e+01 , [Delta: -7.95e+00, ArgProb: 5.76e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp5 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 2.18e+02, currPerf: 4.85e+00, bestPerf: 4.85e+00 , [Delta: 2.13e+02, ArgProb: -3.08e-01, Prob: 0.73]
# 1CEC_p1_PIDD2_exp5 :: Step:    3, Action: Swap        , Temp: 3.33e+01, Card:   2, candPerf: 3.69e+00, currPerf: 4.85e+00, bestPerf: 4.85e+00 , [Delta: -1.16e+00, ArgProb: 2.52e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp5 :: Step:    4, Action: Mirror      , Temp: 2.50e+01, Card:   2, candPerf: 1.42e+01, currPerf: 3.69e+00, bestPerf: 3.69e+00 , [Delta: 1.05e+01, ArgProb: -3.06e-02, Prob: 0.97] A
# 1CEC_p1_PIDD2_exp5 :: Step:    5, Action: Add         , Temp: 2.00e+01, Card:   3, candPerf: 2.17e+00, currPerf: 1.42e+01, bestPerf: 3.69e+00 , [Delta: -1.21e+01, ArgProb: 4.37e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp5 :: Step:    6, Action: Shift       , Temp: 1.67e+01, Card:   3, candPerf: 1.33e+00, currPerf: 2.17e+00, bestPerf: 2.17e+00 , [Delta: -8.36e-01, ArgProb: 3.64e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp5 :: Step:    7, Action: Mirror      , Temp: 1.43e+01, Card:   3, candPerf: 6.97e+00, currPerf: 1.33e+00, bestPerf: 1.33e+00 , [Delta: 5.64e+00, ArgProb: -2.86e-02, Prob: 0.97] A
# 1CEC_p1_PIDD2_exp5 :: Step:    8, Action: Shift       , Temp: 1.25e+01, Card:   3, candPerf: 4.20e+00, currPerf: 6.97e+00, bestPerf: 1.33e+00 , [Delta: -2.77e+00, ArgProb: 1.60e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp5 :: Step:    9, Action: Restart     , Temp: 1.11e+01, Card:   3, candPerf: 3.81e+00, currPerf: 4.20e+00, bestPerf: 1.33e+00 , [Delta: -3.97e-01, ArgProb: 2.59e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp5 :: Step:   10, Action: Roll        , Temp: 1.00e+01, Card:   3, candPerf: 2.69e+00, currPerf: 3.81e+00, bestPerf: 1.33e+00 , [Delta: -1.12e+00, ArgProb: 8.10e-03, Prob: 1.00] A
#
# BEST --> Perf: 1.3291507341656705, e-Sol: [13 20  5]
# Repeticion:
# 6
# 1CEC_p1_PIDD2_exp6 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 8.05e+02 [Initial]
# 1CEC_p1_PIDD2_exp6 :: Step:    1, Action: Roll        , Temp: 1.00e+02, Card:   2, candPerf: 6.31e+02, currPerf: 8.05e+02, bestPerf: 8.05e+02 , [Delta: -1.74e+02, ArgProb: 2.16e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp6 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 4.25e+02, currPerf: 6.31e+02, bestPerf: 6.31e+02 , [Delta: -2.06e+02, ArgProb: 5.11e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp6 :: Step:    3, Action: Restart     , Temp: 3.33e+01, Card:   2, candPerf: 4.33e+00, currPerf: 4.25e+02, bestPerf: 4.25e+02 , [Delta: -4.20e+02, ArgProb: 1.57e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp6 :: Step:    4, Action: Swap        , Temp: 2.50e+01, Card:   2, candPerf: 8.01e+00, currPerf: 4.33e+00, bestPerf: 4.33e+00 , [Delta: 3.68e+00, ArgProb: -1.83e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp6 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   2, candPerf: 5.04e+00, currPerf: 8.01e+00, bestPerf: 4.33e+00 , [Delta: -2.97e+00, ArgProb: 1.85e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp6 :: Step:    6, Action: Swap        , Temp: 1.67e+01, Card:   2, candPerf: 7.17e+00, currPerf: 5.04e+00, bestPerf: 4.33e+00 , [Delta: 2.13e+00, ArgProb: -1.59e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp6 :: Step:    7, Action: Add         , Temp: 1.43e+01, Card:   3, candPerf: 2.02e+00, currPerf: 7.17e+00, bestPerf: 4.33e+00 , [Delta: -5.15e+00, ArgProb: 4.48e-04, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp6 :: Step:    8, Action: RollMany    , Temp: 1.25e+01, Card:   3, candPerf: 1.58e+00, currPerf: 2.02e+00, bestPerf: 2.02e+00 , [Delta: -4.43e-01, ArgProb: 4.40e-05, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp6 :: Step:    9, Action: Mirror      , Temp: 1.11e+01, Card:   3, candPerf: 4.54e+00, currPerf: 1.58e+00, bestPerf: 1.58e+00 , [Delta: 2.96e+00, ArgProb: -3.30e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp6 :: Step:   10, Action: Remove      , Temp: 1.00e+01, Card:   2, candPerf: 4.16e+00, currPerf: 4.54e+00, bestPerf: 1.58e+00 , [Delta: -3.74e-01, ArgProb: 4.64e-05, Prob: 1.00] A
#
# BEST --> Perf: 1.5791701205435746, e-Sol: [22 14 20]
# Repeticion:
# 7
# 1CEC_p1_PIDD2_exp7 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 5.54e+02 [Initial]
# 1CEC_p1_PIDD2_exp7 :: Step:    1, Action: Swap        , Temp: 1.00e+02, Card:   2, candPerf: 2.56e+02, currPerf: 5.54e+02, bestPerf: 5.54e+02 , [Delta: -2.98e+02, ArgProb: 5.37e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp7 :: Step:    2, Action: Add         , Temp: 5.00e+01, Card:   3, candPerf: 3.33e+02, currPerf: 2.56e+02, bestPerf: 2.56e+02 , [Delta: 7.77e+01, ArgProb: -2.80e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp7 :: Step:    3, Action: Shift       , Temp: 3.33e+01, Card:   3, candPerf: 3.55e+00, currPerf: 3.33e+02, bestPerf: 2.56e+02 , [Delta: -3.30e+02, ArgProb: 1.78e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp7 :: Step:    4, Action: Mirror      , Temp: 2.50e+01, Card:   3, candPerf: 8.97e+00, currPerf: 3.55e+00, bestPerf: 3.55e+00 , [Delta: 5.42e+00, ArgProb: -3.91e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp7 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   3, candPerf: 6.24e+00, currPerf: 8.97e+00, bestPerf: 3.55e+00 , [Delta: -2.73e+00, ArgProb: 2.46e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp7 :: Step:    6, Action: RollMany    , Temp: 1.67e+01, Card:   3, candPerf: 6.77e+00, currPerf: 6.24e+00, bestPerf: 3.55e+00 , [Delta: 5.29e-01, ArgProb: -5.72e-05, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp7 :: Step:    7, Action: LocalShift  , Temp: 1.43e+01, Card:   3, candPerf: 1.92e+02, currPerf: 6.77e+00, bestPerf: 3.55e+00 , [Delta: 1.85e+02, ArgProb: -2.33e-02, Prob: 0.98] A
#
# BEST --> Perf: 3.5501044561922637, e-Sol: [ 3  4 10]
# Repeticion:
# 8
# 1CEC_p1_PIDD2_exp8 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.92e+00 [Initial]
# 1CEC_p1_PIDD2_exp8 :: Step:    1, Action: Add         , Temp: 1.00e+02, Card:   3, candPerf: 1.50e+01, currPerf: 1.92e+00, bestPerf: 1.92e+00 , [Delta: 1.30e+01, ArgProb: -4.46e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp8 :: Step:    2, Action: Remove      , Temp: 5.00e+01, Card:   2, candPerf: 1.45e+00, currPerf: 1.50e+01, bestPerf: 1.92e+00 , [Delta: -1.35e+01, ArgProb: 9.25e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp8 :: Step:    3, Action: Add         , Temp: 3.33e+01, Card:   3, candPerf: 1.38e+00, currPerf: 1.45e+00, bestPerf: 1.45e+00 , [Delta: -7.03e-02, ArgProb: 7.21e-04, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp8 :: Step:    4, Action: Remove      , Temp: 2.50e+01, Card:   2, candPerf: 4.50e+00, currPerf: 1.38e+00, bestPerf: 1.38e+00 , [Delta: 3.12e+00, ArgProb: -4.27e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp8 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   2, candPerf: 1.27e+01, currPerf: 4.50e+00, bestPerf: 1.38e+00 , [Delta: 8.22e+00, ArgProb: -1.41e-01, Prob: 0.87]
# 1CEC_p1_PIDD2_exp8 :: Step:    6, Action: LocalShift  , Temp: 1.67e+01, Card:   2, candPerf: 4.29e+00, currPerf: 4.50e+00, bestPerf: 1.38e+00 , [Delta: -2.07e-01, ArgProb: 4.25e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp8 :: Step:    7, Action: Swap        , Temp: 1.43e+01, Card:   2, candPerf: 4.15e+00, currPerf: 4.29e+00, bestPerf: 1.38e+00 , [Delta: -1.46e-01, ArgProb: 3.50e-03, Prob: 1.00] A
#
# BEST --> Perf: 1.3836601577791108, e-Sol: [ 3 22 19]
# Repeticion:
# 9
# 1CEC_p1_PIDD2_exp9 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 5.60e+01 [Initial]
# 1CEC_p1_PIDD2_exp9 :: Step:    1, Action: Shift       , Temp: 1.00e+02, Card:   2, candPerf: 7.68e+00, currPerf: 5.60e+01, bestPerf: 5.60e+01 , [Delta: -4.83e+01, ArgProb: 8.48e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp9 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 8.62e+00, currPerf: 7.68e+00, bestPerf: 7.68e+00 , [Delta: 9.40e-01, ArgProb: -3.30e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp9 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 6.16e+00, currPerf: 8.62e+00, bestPerf: 7.68e+00 , [Delta: -2.46e+00, ArgProb: 1.29e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp9 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 3.99e+00, currPerf: 6.16e+00, bestPerf: 6.16e+00 , [Delta: -2.17e+00, ArgProb: 1.52e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp9 :: Step:    5, Action: Swap        , Temp: 2.00e+01, Card:   3, candPerf: 3.38e+00, currPerf: 3.99e+00, bestPerf: 3.99e+00 , [Delta: -6.10e-01, ArgProb: 5.35e-04, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp9 :: Step:    6, Action: Swap        , Temp: 1.67e+01, Card:   3, candPerf: 4.78e+00, currPerf: 3.38e+00, bestPerf: 3.38e+00 , [Delta: 1.40e+00, ArgProb: -1.47e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp9 :: Step:    7, Action: LocalShift  , Temp: 1.43e+01, Card:   3, candPerf: 1.38e+00, currPerf: 4.78e+00, bestPerf: 3.38e+00 , [Delta: -3.40e+00, ArgProb: 4.17e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp9 :: Step:    8, Action: Roll        , Temp: 1.25e+01, Card:   3, candPerf: 3.42e+00, currPerf: 1.38e+00, bestPerf: 1.38e+00 , [Delta: 2.04e+00, ArgProb: -2.86e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp9 :: Step:    9, Action: LocalShift  , Temp: 1.11e+01, Card:   3, candPerf: 3.59e+00, currPerf: 3.42e+00, bestPerf: 1.38e+00 , [Delta: 1.64e-01, ArgProb: -2.60e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp9 :: Step:   10, Action: Remove      , Temp: 1.00e+01, Card:   2, candPerf: 1.62e+01, currPerf: 3.59e+00, bestPerf: 1.38e+00 , [Delta: 1.27e+01, ArgProb: -2.22e-02, Prob: 0.98] A
#
# BEST --> Perf: 1.383754975418873, e-Sol: [20 13 18]
# Repeticion:
# 10
# 1CEC_p1_PIDD2_exp10 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 4.46e+01 [Initial]
# 1CEC_p1_PIDD2_exp10 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 1.48e+01, currPerf: 4.46e+01, bestPerf: 4.46e+01 , [Delta: -2.98e+01, ArgProb: 6.53e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp10 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 3.57e+01, currPerf: 1.48e+01, bestPerf: 1.48e+01 , [Delta: 2.09e+01, ArgProb: -9.19e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp10 :: Step:    3, Action: Roll        , Temp: 3.33e+01, Card:   2, candPerf: 2.19e+01, currPerf: 3.57e+01, bestPerf: 1.48e+01 , [Delta: -1.38e+01, ArgProb: 9.11e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp10 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 1.25e+01, currPerf: 2.19e+01, bestPerf: 1.48e+01 , [Delta: -9.41e+00, ArgProb: 8.26e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp10 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   3, candPerf: 1.54e+01, currPerf: 1.25e+01, bestPerf: 1.25e+01 , [Delta: 2.89e+00, ArgProb: -3.18e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp10 :: Step:    6, Action: RollMany    , Temp: 1.67e+01, Card:   3, candPerf: 2.04e+01, currPerf: 1.54e+01, bestPerf: 1.25e+01 , [Delta: 5.05e+00, ArgProb: -6.64e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp10 :: Step:    7, Action: LocalShift  , Temp: 1.43e+01, Card:   3, candPerf: 5.72e+00, currPerf: 2.04e+01, bestPerf: 1.25e+01 , [Delta: -1.47e+01, ArgProb: 2.26e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp10 :: Step:    8, Action: Roll        , Temp: 1.25e+01, Card:   3, candPerf: 1.21e+01, currPerf: 5.72e+00, bestPerf: 5.72e+00 , [Delta: 6.36e+00, ArgProb: -1.12e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp10 :: Step:    9, Action: Shift       , Temp: 1.11e+01, Card:   3, candPerf: 1.40e+01, currPerf: 1.21e+01, bestPerf: 5.72e+00 , [Delta: 1.94e+00, ArgProb: -3.82e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp10 :: Step:   10, Action: Remove      , Temp: 1.00e+01, Card:   2, candPerf: 1.01e+02, currPerf: 1.40e+01, bestPerf: 5.72e+00 , [Delta: 8.75e+01, ArgProb: -1.92e-01, Prob: 0.83]
#
# BEST --> Perf: 5.724500764953451, e-Sol: [ 4 13 17]
# Repeticion:
# 11
# 1CEC_p1_PIDD2_exp11 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.27e+02 [Initial]
# 1CEC_p1_PIDD2_exp11 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 5.92e+01, currPerf: 1.27e+02, bestPerf: 1.27e+02 , [Delta: -6.79e+01, ArgProb: 5.30e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp11 :: Step:    2, Action: Shift       , Temp: 5.00e+01, Card:   2, candPerf: 8.77e+01, currPerf: 5.92e+01, bestPerf: 5.92e+01 , [Delta: 2.85e+01, ArgProb: -4.46e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp11 :: Step:    3, Action: Restart     , Temp: 3.33e+01, Card:   2, candPerf: 1.36e+02, currPerf: 8.77e+01, bestPerf: 5.92e+01 , [Delta: 4.85e+01, ArgProb: -1.14e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp11 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 1.00e+02, currPerf: 1.36e+02, bestPerf: 5.92e+01 , [Delta: -3.59e+01, ArgProb: 1.12e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp11 :: Step:    5, Action: Roll        , Temp: 2.00e+01, Card:   2, candPerf: 9.84e+01, currPerf: 1.00e+02, bestPerf: 5.92e+01 , [Delta: -1.92e+00, ArgProb: 7.49e-04, Prob: 1.00] A
#
# BEST --> Perf: 59.15030088970354, e-Sol: [19  9]
# Repeticion:
# 12
# 1CEC_p1_PIDD2_exp12 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.52e+01 [Initial]
# 1CEC_p1_PIDD2_exp12 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 5.11e+01, currPerf: 1.52e+01, bestPerf: 1.52e+01 , [Delta: 3.59e+01, ArgProb: -2.21e-02, Prob: 0.98] A
# 1CEC_p1_PIDD2_exp12 :: Step:    2, Action: Roll        , Temp: 5.00e+01, Card:   2, candPerf: 8.59e+00, currPerf: 5.11e+01, bestPerf: 1.52e+01 , [Delta: -4.25e+01, ArgProb: 5.24e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp12 :: Step:    3, Action: Mirror      , Temp: 3.33e+01, Card:   2, candPerf: 2.85e+01, currPerf: 8.59e+00, bestPerf: 8.59e+00 , [Delta: 1.99e+01, ArgProb: -3.68e-02, Prob: 0.96] A
# 1CEC_p1_PIDD2_exp12 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 5.55e+00, currPerf: 2.85e+01, bestPerf: 8.59e+00 , [Delta: -2.29e+01, ArgProb: 5.66e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp12 :: Step:    5, Action: Restart     , Temp: 2.00e+01, Card:   3, candPerf: 6.49e+00, currPerf: 5.55e+00, bestPerf: 5.55e+00 , [Delta: 9.41e-01, ArgProb: -2.90e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp12 :: Step:    6, Action: Restart     , Temp: 1.67e+01, Card:   3, candPerf: 1.10e+02, currPerf: 6.49e+00, bestPerf: 5.55e+00 , [Delta: 1.03e+02, ArgProb: -3.82e-01, Prob: 0.68] A
# 1CEC_p1_PIDD2_exp12 :: Step:    7, Action: Remove      , Temp: 1.43e+01, Card:   2, candPerf: 3.11e+02, currPerf: 1.10e+02, bestPerf: 5.55e+00 , [Delta: 2.01e+02, ArgProb: -8.67e-01, Prob: 0.42]
# 1CEC_p1_PIDD2_exp12 :: Step:    8, Action: Restart     , Temp: 1.25e+01, Card:   3, candPerf: 5.77e+01, currPerf: 1.10e+02, bestPerf: 5.55e+00 , [Delta: -5.20e+01, ArgProb: 2.57e-01, Prob: 1.00] A
#
# BEST --> Perf: 5.548976790316614, e-Sol: [12 15 23]
# Repeticion:
# 13
# 1CEC_p1_PIDD2_exp13 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 6.32e+01 [Initial]
# 1CEC_p1_PIDD2_exp13 :: Step:    1, Action: LocalShift  , Temp: 1.00e+02, Card:   2, candPerf: 1.36e+03, currPerf: 6.32e+01, bestPerf: 6.32e+01 , [Delta: 1.30e+03, ArgProb: -2.03e-01, Prob: 0.82]
# 1CEC_p1_PIDD2_exp13 :: Step:    2, Action: LocalShift  , Temp: 5.00e+01, Card:   2, candPerf: 4.55e+02, currPerf: 6.32e+01, bestPerf: 6.32e+01 , [Delta: 3.91e+02, ArgProb: -1.22e-01, Prob: 0.89] A
# 1CEC_p1_PIDD2_exp13 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 1.15e+03, currPerf: 4.55e+02, bestPerf: 6.32e+01 , [Delta: 6.99e+02, ArgProb: -3.26e-01, Prob: 0.72]
# 1CEC_p1_PIDD2_exp13 :: Step:    4, Action: Restart     , Temp: 2.50e+01, Card:   2, candPerf: 4.53e+00, currPerf: 4.55e+02, bestPerf: 6.32e+01 , [Delta: -4.50e+02, ArgProb: 2.80e-01, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp13 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   2, candPerf: 5.85e+00, currPerf: 4.53e+00, bestPerf: 4.53e+00 , [Delta: 1.32e+00, ArgProb: -1.03e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp13 :: Step:    6, Action: Add         , Temp: 1.67e+01, Card:   3, candPerf: 9.53e-01, currPerf: 5.85e+00, bestPerf: 4.53e+00 , [Delta: -4.89e+00, ArgProb: 4.57e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp13 :: Step:    7, Action: Restart     , Temp: 1.43e+01, Card:   3, candPerf: 1.10e+01, currPerf: 9.53e-01, bestPerf: 9.53e-01 , [Delta: 1.00e+01, ArgProb: -1.09e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp13 :: Step:    8, Action: Roll        , Temp: 1.25e+01, Card:   3, candPerf: 1.61e+01, currPerf: 1.10e+01, bestPerf: 9.53e-01 , [Delta: 5.15e+00, ArgProb: -6.41e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp13 :: Step:    9, Action: Mirror      , Temp: 1.11e+01, Card:   3, candPerf: 8.01e+00, currPerf: 1.61e+01, bestPerf: 9.53e-01 , [Delta: -8.13e+00, ArgProb: 1.14e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp13 :: Step:   10, Action: Restart     , Temp: 1.00e+01, Card:   3, candPerf: 2.22e+01, currPerf: 8.01e+00, bestPerf: 9.53e-01 , [Delta: 1.42e+01, ArgProb: -2.22e-02, Prob: 0.98] A
#
# BEST --> Perf: 0.9533133383589647, e-Sol: [23  3 12]
# Repeticion:
# 14
# 1CEC_p1_PIDD2_exp14 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 1.37e+01 [Initial]
# 1CEC_p1_PIDD2_exp14 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 1.30e+01, currPerf: 1.37e+01, bestPerf: 1.37e+01 , [Delta: -7.29e-01, ArgProb: 4.96e-04, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp14 :: Step:    2, Action: Mirror      , Temp: 5.00e+01, Card:   2, candPerf: 6.66e+00, currPerf: 1.30e+01, bestPerf: 1.30e+01 , [Delta: -6.29e+00, ArgProb: 8.58e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp14 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 4.25e+01, currPerf: 6.66e+00, bestPerf: 6.66e+00 , [Delta: 3.58e+01, ArgProb: -7.32e-02, Prob: 0.93] A
# 1CEC_p1_PIDD2_exp14 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 2.79e+01, currPerf: 4.25e+01, bestPerf: 6.66e+00 , [Delta: -1.46e+01, ArgProb: 3.97e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp14 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   3, candPerf: 1.23e+01, currPerf: 2.79e+01, bestPerf: 6.66e+00 , [Delta: -1.56e+01, ArgProb: 5.32e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp14 :: Step:    6, Action: Restart     , Temp: 1.67e+01, Card:   3, candPerf: 5.96e+01, currPerf: 1.23e+01, bestPerf: 6.66e+00 , [Delta: 4.73e+01, ArgProb: -1.93e-01, Prob: 0.82] A
#
# BEST --> Perf: 6.658165130012184, e-Sol: [15 18]
# Repeticion:
# 15
# 1CEC_p1_PIDD2_exp15 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 6.66e+02 [Initial]
# 1CEC_p1_PIDD2_exp15 :: Step:    1, Action: Roll        , Temp: 1.00e+02, Card:   2, candPerf: 5.09e+02, currPerf: 6.66e+02, bestPerf: 6.66e+02 , [Delta: -1.58e+02, ArgProb: 2.36e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp15 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 8.67e+02, currPerf: 5.09e+02, bestPerf: 5.09e+02 , [Delta: 3.58e+02, ArgProb: -1.07e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp15 :: Step:    3, Action: Swap        , Temp: 3.33e+01, Card:   2, candPerf: 4.06e+02, currPerf: 8.67e+02, bestPerf: 5.09e+02 , [Delta: -4.61e+02, ArgProb: 2.07e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp15 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 8.49e+01, currPerf: 4.06e+02, bestPerf: 4.06e+02 , [Delta: -3.21e+02, ArgProb: 1.92e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp15 :: Step:    5, Action: RollMany    , Temp: 2.00e+01, Card:   2, candPerf: 7.13e+01, currPerf: 8.49e+01, bestPerf: 8.49e+01 , [Delta: -1.36e+01, ArgProb: 1.02e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp15 :: Step:    6, Action: Shift       , Temp: 1.67e+01, Card:   2, candPerf: 2.02e+02, currPerf: 7.13e+01, bestPerf: 7.13e+01 , [Delta: 1.31e+02, ArgProb: -1.18e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp15 :: Step:    7, Action: RollMany    , Temp: 1.43e+01, Card:   2, candPerf: 4.23e+02, currPerf: 2.02e+02, bestPerf: 7.13e+01 , [Delta: 2.20e+02, ArgProb: -2.31e-02, Prob: 0.98] A
# 1CEC_p1_PIDD2_exp15 :: Step:    8, Action: LocalShift  , Temp: 1.25e+01, Card:   2, candPerf: 3.84e+01, currPerf: 4.23e+02, bestPerf: 7.13e+01 , [Delta: -3.84e+02, ArgProb: 4.61e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp15 :: Step:    9, Action: LocalShift  , Temp: 1.11e+01, Card:   2, candPerf: 3.84e+01, currPerf: 3.84e+01, bestPerf: 3.84e+01 , [Delta: 1.98e-02, ArgProb: -2.67e-06, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp15 :: Step:   10, Action: Add         , Temp: 1.00e+01, Card:   3, candPerf: 5.03e+00, currPerf: 3.84e+01, bestPerf: 3.84e+01 , [Delta: -3.34e+01, ArgProb: 5.01e-03, Prob: 1.00] A+
#
# BEST --> Perf: 5.033992850126834, e-Sol: [21  6 23]
# Repeticion:
# 16
# 1CEC_p1_PIDD2_exp16 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 9.50e+00 [Initial]
# 1CEC_p1_PIDD2_exp16 :: Step:    1, Action: Mirror      , Temp: 1.00e+02, Card:   2, candPerf: 1.83e+01, currPerf: 9.50e+00, bestPerf: 9.50e+00 , [Delta: 8.78e+00, ArgProb: -8.36e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp16 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 1.02e+01, currPerf: 1.83e+01, bestPerf: 9.50e+00 , [Delta: -8.07e+00, ArgProb: 1.54e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp16 :: Step:    3, Action: Mirror      , Temp: 3.33e+01, Card:   2, candPerf: 1.10e+01, currPerf: 1.02e+01, bestPerf: 9.50e+00 , [Delta: 7.97e-01, ArgProb: -2.28e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp16 :: Step:    4, Action: Add         , Temp: 2.50e+01, Card:   3, candPerf: 1.02e+01, currPerf: 1.10e+01, bestPerf: 9.50e+00 , [Delta: -7.54e-01, ArgProb: 2.87e-03, Prob: 1.00] A
#
# BEST --> Perf: 9.498346723828538, e-Sol: [ 2 16]
# Repeticion:
# 17
# 1CEC_p1_PIDD2_exp17 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 5.17e+02 [Initial]
# 1CEC_p1_PIDD2_exp17 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 5.83e+02, currPerf: 5.17e+02, bestPerf: 5.17e+02 , [Delta: 6.57e+01, ArgProb: -1.27e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp17 :: Step:    2, Action: Restart     , Temp: 5.00e+01, Card:   2, candPerf: 6.83e+01, currPerf: 5.83e+02, bestPerf: 5.17e+02 , [Delta: -5.14e+02, ArgProb: 1.99e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp17 :: Step:    3, Action: Roll        , Temp: 3.33e+01, Card:   2, candPerf: 3.89e+01, currPerf: 6.83e+01, bestPerf: 6.83e+01 , [Delta: -2.94e+01, ArgProb: 1.71e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp17 :: Step:    4, Action: Roll        , Temp: 2.50e+01, Card:   2, candPerf: 2.39e+01, currPerf: 3.89e+01, bestPerf: 3.89e+01 , [Delta: -1.50e+01, ArgProb: 1.16e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp17 :: Step:    5, Action: RollMany    , Temp: 2.00e+01, Card:   2, candPerf: 1.44e+02, currPerf: 2.39e+01, bestPerf: 2.39e+01 , [Delta: 1.20e+02, ArgProb: -1.16e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp17 :: Step:    6, Action: Swap        , Temp: 1.67e+01, Card:   2, candPerf: 8.47e+01, currPerf: 1.44e+02, bestPerf: 2.39e+01 , [Delta: -5.96e+01, ArgProb: 6.91e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp17 :: Step:    7, Action: Restart     , Temp: 1.43e+01, Card:   2, candPerf: 8.19e+01, currPerf: 8.47e+01, bestPerf: 2.39e+01 , [Delta: -2.75e+00, ArgProb: 3.71e-04, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp17 :: Step:    8, Action: Shift       , Temp: 1.25e+01, Card:   2, candPerf: 2.09e+01, currPerf: 8.19e+01, bestPerf: 2.39e+01 , [Delta: -6.10e+01, ArgProb: 9.43e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp17 :: Step:    9, Action: LocalShift  , Temp: 1.11e+01, Card:   2, candPerf: 8.99e+00, currPerf: 2.09e+01, bestPerf: 2.09e+01 , [Delta: -1.19e+01, ArgProb: 2.07e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp17 :: Step:   10, Action: Add         , Temp: 1.00e+01, Card:   3, candPerf: 2.49e+00, currPerf: 8.99e+00, bestPerf: 8.99e+00 , [Delta: -6.50e+00, ArgProb: 1.25e-03, Prob: 1.00] A+
#
# BEST --> Perf: 2.4945469073452538, e-Sol: [ 5 23 20]
# Repeticion:
# 18
# 1CEC_p1_PIDD2_exp18 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 3.55e+01 [Initial]
# 1CEC_p1_PIDD2_exp18 :: Step:    1, Action: RollMany    , Temp: 1.00e+02, Card:   2, candPerf: 4.41e+01, currPerf: 3.55e+01, bestPerf: 3.55e+01 , [Delta: 8.58e+00, ArgProb: -2.35e-03, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp18 :: Step:    2, Action: Restart     , Temp: 5.00e+01, Card:   2, candPerf: 4.95e+02, currPerf: 4.41e+01, bestPerf: 3.55e+01 , [Delta: 4.51e+02, ArgProb: -2.47e-01, Prob: 0.78] A
# 1CEC_p1_PIDD2_exp18 :: Step:    3, Action: Swap        , Temp: 3.33e+01, Card:   2, candPerf: 3.83e+02, currPerf: 4.95e+02, bestPerf: 3.55e+01 , [Delta: -1.12e+02, ArgProb: 9.20e-02, Prob: 1.00] A
# 1CEC_p1_PIDD2_exp18 :: Step:    4, Action: LocalShift  , Temp: 2.50e+01, Card:   2, candPerf: 1.56e+01, currPerf: 3.83e+02, bestPerf: 3.55e+01 , [Delta: -3.67e+02, ArgProb: 4.03e-01, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp18 :: Step:    5, Action: Mirror      , Temp: 2.00e+01, Card:   2, candPerf: 1.09e+02, currPerf: 1.56e+01, bestPerf: 1.56e+01 , [Delta: 9.31e+01, ArgProb: -1.28e-01, Prob: 0.88] A
# 1CEC_p1_PIDD2_exp18 :: Step:    6, Action: Shift       , Temp: 1.67e+01, Card:   2, candPerf: 1.12e+01, currPerf: 1.09e+02, bestPerf: 1.56e+01 , [Delta: -9.75e+01, ArgProb: 1.60e-01, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp18 :: Step:    7, Action: Swap        , Temp: 1.43e+01, Card:   2, candPerf: 8.41e+00, currPerf: 1.12e+01, bestPerf: 1.12e+01 , [Delta: -2.80e+00, ArgProb: 5.37e-03, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp18 :: Step:    8, Action: RollMany    , Temp: 1.25e+01, Card:   2, candPerf: 1.22e+01, currPerf: 8.41e+00, bestPerf: 8.41e+00 , [Delta: 3.74e+00, ArgProb: -8.20e-03, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp18 :: Step:    9, Action: Swap        , Temp: 1.11e+01, Card:   2, candPerf: 5.86e+00, currPerf: 1.22e+01, bestPerf: 8.41e+00 , [Delta: -6.29e+00, ArgProb: 1.55e-02, Prob: 1.00] A+
# 1CEC_p1_PIDD2_exp18 :: Step:   10, Action: Swap        , Temp: 1.00e+01, Card:   2, candPerf: 2.66e+01, currPerf: 5.86e+00, bestPerf: 5.86e+00 , [Delta: 2.08e+01, ArgProb: -5.69e-02, Prob: 0.94] A
#
# BEST --> Perf: 5.864715289032129, e-Sol: [18 12]
# Repeticion:
# 19
# 1CEC_p1_PIDD2_exp19 :: Step:    0, Action: None        , Temp: 1.00e+02, Card:   2, Perf: 4.09e+00 [Initial]
# 1CEC_p1_PIDD2_exp19 :: Step:    1, Action: LocalShift  , Temp: 1.00e+02, Card:   2, candPerf: 9.81e+02, currPerf: 4.09e+00, bestPerf: 4.09e+00 , [Delta: 9.77e+02, ArgProb: -1.92e+00, Prob: 0.15]
# 1CEC_p1_PIDD2_exp19 :: Step:    2, Action: Swap        , Temp: 5.00e+01, Card:   2, candPerf: 6.74e+00, currPerf: 4.09e+00, bestPerf: 4.09e+00 , [Delta: 2.65e+00, ArgProb: -1.04e-02, Prob: 0.99] A
# 1CEC_p1_PIDD2_exp19 :: Step:    3, Action: LocalShift  , Temp: 3.33e+01, Card:   2, candPerf: 8.72e+02, currPerf: 6.74e+00, bestPerf: 4.09e+00 , [Delta: 8.65e+02, ArgProb: -5.10e+00, Prob: 0.01]
# 1CEC_p1_PIDD2_exp19 :: Step:    4, Action: Restart     , Temp: 2.50e+01, Card:   2, candPerf: 1.94e+01, currPerf: 6.74e+00, bestPerf: 4.09e+00 , [Delta: 1.27e+01, ArgProb: -9.97e-02, Prob: 0.91] A
#
# BEST --> Perf: 4.090954833531538, e-Sol: [10  2]
